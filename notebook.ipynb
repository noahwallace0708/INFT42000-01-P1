# %% [markdown]
# INFT42000-01-P1
# basic python app for git

# %%
#imports
import pandas as pd
import numpy as np
print("libs loaded")
# Out:
# libs loaded

# %%
#set up data
time = [30, 45, 60, 2]

# %%
#create a series
series = pd.Series(time)

# print the average of the series
print(f"average: {series.mean()} minutes")
# Out:
# average: 34.25 minutes
